# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

# %%
#to read table
df=spark.read.table("Employeedata")
df.show()
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 47, Finished, Available, Finished, False)
# +----------+------------+----------+------+---------+---+
# |EmployeeID|EmployeeName|Department|Salary|     City|Age|
# +----------+------------+----------+------+---------+---+
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# +----------+------------+----------+------+---------+---+

# %%
# Read data into a DataFrame
# If your data is in a Lakehouse table
df = spark.read.table("Employeedata")

# Display the data
df.show()

# Check the schema
df.printSchema()

# Print the DataFrame object
print(df)

# Count the number of rows
print("Total Rows:", df.count())

# Rename the EmployeeName column to Name
df = df.withColumnRenamed("EmployeeName", "Name")

# Verify the renamed column
df.printSchema()

# Display the updated DataFrame
df.show()
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 22, Finished, Available, Finished, False)
# +----------+------------+----------+------+---------+---+
# |EmployeeID|EmployeeName|Department|Salary|     City|Age|
# +----------+------------+----------+------+---------+---+
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# +----------+------------+----------+------+---------+---+
#
# root
#  |-- EmployeeID: integer (nullable = true)
#  |-- EmployeeName: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Salary: integer (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Age: integer (nullable = true)
#
# DataFrame[EmployeeID: int, EmployeeName: string, Department: string, Salary: int, City: string, Age: int]
# Total Rows: 10
# root
#  |-- EmployeeID: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- Salary: integer (nullable = true)
#  |-- City: string (nullable = true)
#  |-- Age: integer (nullable = true)
#
# +----------+------+----------+------+---------+---+
# |EmployeeID|  Name|Department|Salary|     City|Age|
# +----------+------+----------+------+---------+---+
# |       101|  John|        IT| 65000|  Chennai| 25|
# |       102| Alice|        HR| 55000|Bangalore| 28|
# |       103| David|   Finance| 70000|Hyderabad| 32|
# |       104|Monica|        IT| 75000|  Chennai| 27|
# |       105|  Sara|     Sales| 60000|   Mumbai| 29|
# |       101|  John|        IT| 65000|  Chennai| 25|
# |       102| Alice|        HR| 55000|Bangalore| 28|
# |       103| David|   Finance| 70000|Hyderabad| 32|
# |       104|Monica|        IT| 75000|  Chennai| 27|
# |       105|  Sara|     Sales| 60000|   Mumbai| 29|
# +----------+------+----------+------+---------+---+

# %%
#to add bonus column
from pyspark.sql.functions import col
df=df.withColumn(
    "Bonus",
     col("Salary")*0.10
)
df.show()
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 29, Finished, Available, Finished, False)
# +----------+------+----------+------+---------+---+------+
# |EmployeeID|  Name|Department|Salary|     City|Age| Bonus|
# +----------+------+----------+------+---------+---+------+
# |       101|  John|        IT| 65000|  Chennai| 25|6500.0|
# |       102| Alice|        HR| 55000|Bangalore| 28|5500.0|
# |       103| David|   Finance| 70000|Hyderabad| 32|7000.0|
# |       104|Monica|        IT| 75000|  Chennai| 27|7500.0|
# |       105|  Sara|     Sales| 60000|   Mumbai| 29|6000.0|
# |       101|  John|        IT| 65000|  Chennai| 25|6500.0|
# |       102| Alice|        HR| 55000|Bangalore| 28|5500.0|
# |       103| David|   Finance| 70000|Hyderabad| 32|7000.0|
# |       104|Monica|        IT| 75000|  Chennai| 27|7500.0|
# |       105|  Sara|     Sales| 60000|   Mumbai| 29|6000.0|
# +----------+------+----------+------+---------+---+------+

# %%
df=df.filter(df.Salary>50000)
df.show()
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 49, Finished, Available, Finished, False)
# +----------+------------+----------+------+---------+---+
# |EmployeeID|EmployeeName|Department|Salary|     City|Age|
# +----------+------------+----------+------+---------+---+
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# +----------+------------+----------+------+---------+---+

# %%
df.orderBy("Salary").show()
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 51, Finished, Available, Finished, False)
# +----------+------------+----------+------+---------+---+
# |EmployeeID|EmployeeName|Department|Salary|     City|Age|
# +----------+------------+----------+------+---------+---+
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       102|       Alice|        HR| 55000|Bangalore| 28|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# |       105|        Sara|     Sales| 60000|   Mumbai| 29|
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       101|        John|        IT| 65000|  Chennai| 25|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       103|       David|   Finance| 70000|Hyderabad| 32|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# |       104|      Monica|        IT| 75000|  Chennai| 27|
# +----------+------------+----------+------+---------+---+

# %%
df.write.mode("overwrite").saveAsTable("Employee_Transformed")
# Out:
# StatementMeta(, 5542c06b-0e66-4657-a94e-3072c295f9ba, 52, Finished, Available, Finished, False)
